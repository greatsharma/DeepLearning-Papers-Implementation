# %%
! pip install scikit-plot tensorflow=='2.2.0-rc3'
# Out:
# ERROR: Invalid requirement: 'scikit-plot,'

# %%
! pip install wandb --upgrade
# Out:
# Requirement already up-to-date: wandb in /usr/local/lib/python3.6/dist-packages (0.8.36)
# Requirement already satisfied, skipping upgrade: GitPython>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (3.1.2)
# Requirement already satisfied, skipping upgrade: PyYAML>=3.10 in /usr/local/lib/python3.6/dist-packages (from wandb) (3.13)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.8.1)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (1.12.0)
# Requirement already satisfied, skipping upgrade: sentry-sdk>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.14.4)
# Requirement already satisfied, skipping upgrade: psutil>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied, skipping upgrade: subprocess32>=3.5.3 in /usr/local/lib/python3.6/dist-packages (from wandb) (3.5.4)
# Requirement already satisfied, skipping upgrade: gql==0.2.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.2.0)
# Requirement already satisfied, skipping upgrade: shortuuid>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (1.0.1)
# Requirement already satisfied, skipping upgrade: docker-pycreds>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied, skipping upgrade: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (7.352.0)
# Requirement already satisfied, skipping upgrade: configparser>=3.8.1 in /usr/local/lib/python3.6/dist-packages (from wandb) (5.0.0)
# Requirement already satisfied, skipping upgrade: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied, skipping upgrade: watchdog>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from wandb) (0.10.2)
# Requirement already satisfied, skipping upgrade: gitdb<5,>=4.0.1 in /usr/local/lib/python3.6/dist-packages (from GitPython>=1.0.0->wandb) (4.0.5)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb) (2.9)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied, skipping upgrade: promise<3,>=2.0 in /usr/local/lib/python3.6/dist-packages (from gql==0.2.0->wandb) (2.3)
# Requirement already satisfied, skipping upgrade: graphql-core<2,>=0.5.0 in /usr/local/lib/python3.6/dist-packages (from gql==0.2.0->wandb) (1.1)
# Requirement already satisfied, skipping upgrade: pathtools>=0.1.1 in /usr/local/lib/python3.6/dist-packages (from watchdog>=0.8.3->wandb) (0.1.2)
# Requirement already satisfied, skipping upgrade: smmap<4,>=3.0.1 in /usr/local/lib/python3.6/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (3.0.4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from zipfile import ZipFile 

DATA = "feraligned+ck"
file_name = f"drive/My Drive/FER/datasets/{DATA}.zip"

with ZipFile(file_name, 'r') as zip_:
    print('Extracting all the files...') 
    zip_.extractall(DATA)
    print('Done!')
# Out:
# Extracting all the files...
# Done!

# %%
import os
import cv2
import math
import joblib
import numpy as np

import scikitplot
import seaborn as sns
from matplotlib import pyplot

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten, Dense, Conv2D, ZeroPadding2D, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation, Dropout, BatchNormalization, Concatenate
from tensorflow.keras.initializers import he_normal
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

import wandb
from wandb.keras import WandbCallback

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
BASE_PATH = "drive/My Drive/FER/Colab/GauravSharma/AdvancedNetworks/"
DATA_PATH = f"{DATA}/{DATA}/"
TOP_EMOTIONS = ["Happy", "Neutral", "Sadness"]

TRAIN_SIZE = 0.86
INPUT_SHAPE = (48,48,1)
NUM_CLASSES = len(TOP_EMOTIONS)

# %%
total_images = 0
for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        count = 0
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            count += 1
        print(f"{dir_} has {count} number of images")
        total_images += count

print(f"\ntotal images are {total_images}")
# Out:
# Happy has 2203 number of images
# Neutral has 1230 number of images
# Sadness has 1153 number of images
#
# total images are 4586

# %%
img_arr = []
img_label = []
label_to_text = {}
label = 0

for dir_ in os.listdir(DATA_PATH):
    if dir_ in TOP_EMOTIONS:
        for f in os.listdir(DATA_PATH + dir_ + "/"):
            img_arr.append(np.expand_dims(cv2.imread(DATA_PATH + dir_ + "/" + f, 0), axis=2))
            img_label.append(label)
        print(f"loaded {dir_} images to numpy arrays...")
        label_to_text[label] = dir_
        label += 1

img_arr = np.array(img_arr)
img_label = np.array(img_label)
img_label = OneHotEncoder(sparse=False).fit_transform(img_label.reshape(-1,1))

img_arr.shape, img_label.shape, label_to_text
# Out:
# loaded Happy images to numpy arrays...
# loaded Neutral images to numpy arrays...
# loaded Sadness images to numpy arrays...
# ((4586, 48, 48, 1), (4586, 3), {0: 'Happy', 1: 'Neutral', 2: 'Sadness'})

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=TRAIN_SIZE, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3943, 48, 48, 1), (643, 48, 48, 1), (3943, 3), (643, 3))

# %%
def transition_cell(X, filters: int, compression_factor: float, cell_id: int):
    num_fm = X.shape[1]

    X = BatchNormalization(name=f"transition{cell_id}_bn")(X)
    X = Activation('relu', name=f"transition{cell_id}_actv")(X)
    X = Conv2D(
        np.floor(compression_factor * num_fm ).astype( np.int ),
        kernel_size=(1, 1),
        padding='same',
        kernel_initializer=he_normal(seed=42),
        name=f"transition{cell_id}_conv2d",
    )(X)
    
    X = AveragePooling2D(pool_size=(2, 2), name=f"transition{cell_id}_pool2d")(X)
    return X

# %%
def dense_block(inputs, num_layers: int, filters: int, growth_rate: float, block_id: int):
    layer_id = 1
    for i in range(num_layers):
        X = BatchNormalization(name=f"block{block_id}_bn{layer_id}")(inputs)
        X = Activation('relu', name=f"block{block_id}_actv{layer_id}")(X)
        X = ZeroPadding2D((1, 1), name=f"block{block_id}_pad{layer_id}")(X)
        X = Conv2D(
            filters,
            kernel_size=(3, 3),
            kernel_initializer=he_normal(seed=42),
            name = f"block{block_id}_conv2d{layer_id}"
        )(X)
        inputs = Concatenate(name=f"block{block_id}_concat{layer_id}")([X, inputs])
        filters += growth_rate
        layer_id += 1
    
    return inputs, filters

# %%
def DenseNet(in_shape, out_shape, num_blocks=3, layers_per_block=3, growth_rate=12,
             compress_factor=0.5, initial_filters=12, dropout_rate=0.3, show_summary=False):

    model_in = Input(shape=in_shape, name="in_layer")

    X = Conv2D(
        initial_filters,
        kernel_size=(3,3),
        strides = (1,1),
        padding = 'valid',
        kernel_initializer=he_normal(seed=42),
        name = "conv2d_0"
    )(model_in)

    block_id = 1
    num_filters = initial_filters
    for i in range(num_blocks):
        X, num_filters = dense_block(X, layers_per_block, num_filters, growth_rate, block_id=block_id)
        X = transition_cell(X, num_filters, compress_factor, cell_id=block_id)
        block_id += 1

    X = GlobalAveragePooling2D()(X)
    X = Flatten()(X)

    X = Dense(units=128, name="dense1")(X)
    X = BatchNormalization(name = 'dense1_bn')(X)
    X = Activation('relu', name="dense1_actv")(X)

    model_out = Dense(out_shape, activation="softmax")(X)

    model = Model(model_in, model_out)
    
    if show_summary:
        model.summary()

    return model

# %%
model = DenseNet(INPUT_SHAPE, NUM_CLASSES, num_blocks=3, layers_per_block=3, show_summary=True)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# in_layer (InputLayer)           [(None, 48, 48, 1)]  0
# __________________________________________________________________________________________________
# conv2d_0 (Conv2D)               (None, 46, 46, 12)   120         in_layer[0][0]
# __________________________________________________________________________________________________
# block1_bn1 (BatchNormalization) (None, 46, 46, 12)   48          conv2d_0[0][0]
# __________________________________________________________________________________________________
# block1_actv1 (Activation)       (None, 46, 46, 12)   0           block1_bn1[0][0]
# __________________________________________________________________________________________________
# block1_pad1 (ZeroPadding2D)     (None, 48, 48, 12)   0           block1_actv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2d1 (Conv2D)         (None, 46, 46, 12)   1308        block1_pad1[0][0]
# __________________________________________________________________________________________________
# block1_concat1 (Concatenate)    (None, 46, 46, 24)   0           block1_conv2d1[0][0]
#                                                                  conv2d_0[0][0]
# __________________________________________________________________________________________________
# block1_bn2 (BatchNormalization) (None, 46, 46, 24)   96          block1_concat1[0][0]
# __________________________________________________________________________________________________
# block1_actv2 (Activation)       (None, 46, 46, 24)   0           block1_bn2[0][0]
# __________________________________________________________________________________________________
# block1_pad2 (ZeroPadding2D)     (None, 48, 48, 24)   0           block1_actv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2d2 (Conv2D)         (None, 46, 46, 24)   5208        block1_pad2[0][0]
# __________________________________________________________________________________________________
# block1_concat2 (Concatenate)    (None, 46, 46, 48)   0           block1_conv2d2[0][0]
#                                                                  block1_concat1[0][0]
# __________________________________________________________________________________________________
# block1_bn3 (BatchNormalization) (None, 46, 46, 48)   192         block1_concat2[0][0]
# __________________________________________________________________________________________________
# block1_actv3 (Activation)       (None, 46, 46, 48)   0           block1_bn3[0][0]
# __________________________________________________________________________________________________
# block1_pad3 (ZeroPadding2D)     (None, 48, 48, 48)   0           block1_actv3[0][0]
# __________________________________________________________________________________________________
# block1_conv2d3 (Conv2D)         (None, 46, 46, 36)   15588       block1_pad3[0][0]
# __________________________________________________________________________________________________
# block1_concat3 (Concatenate)    (None, 46, 46, 84)   0           block1_conv2d3[0][0]
#                                                                  block1_concat2[0][0]
# __________________________________________________________________________________________________
# transition1_bn (BatchNormalizat (None, 46, 46, 84)   336         block1_concat3[0][0]
# __________________________________________________________________________________________________
# transition1_actv (Activation)   (None, 46, 46, 84)   0           transition1_bn[0][0]
# __________________________________________________________________________________________________
# transition1_conv2d (Conv2D)     (None, 46, 46, 23)   1955        transition1_actv[0][0]
# __________________________________________________________________________________________________
# transition1_pool2d (AveragePool (None, 23, 23, 23)   0           transition1_conv2d[0][0]
# __________________________________________________________________________________________________
# block2_bn1 (BatchNormalization) (None, 23, 23, 23)   92          transition1_pool2d[0][0]
# __________________________________________________________________________________________________
# block2_actv1 (Activation)       (None, 23, 23, 23)   0           block2_bn1[0][0]
# __________________________________________________________________________________________________
# block2_pad1 (ZeroPadding2D)     (None, 25, 25, 23)   0           block2_actv1[0][0]
# __________________________________________________________________________________________________
# block2_conv2d1 (Conv2D)         (None, 23, 23, 48)   9984        block2_pad1[0][0]
# __________________________________________________________________________________________________
# block2_concat1 (Concatenate)    (None, 23, 23, 71)   0           block2_conv2d1[0][0]
#                                                                  transition1_pool2d[0][0]
# __________________________________________________________________________________________________
# block2_bn2 (BatchNormalization) (None, 23, 23, 71)   284         block2_concat1[0][0]
# __________________________________________________________________________________________________
# block2_actv2 (Activation)       (None, 23, 23, 71)   0           block2_bn2[0][0]
# __________________________________________________________________________________________________
# block2_pad2 (ZeroPadding2D)     (None, 25, 25, 71)   0           block2_actv2[0][0]
# __________________________________________________________________________________________________
# block2_conv2d2 (Conv2D)         (None, 23, 23, 60)   38400       block2_pad2[0][0]
# __________________________________________________________________________________________________
# block2_concat2 (Concatenate)    (None, 23, 23, 131)  0           block2_conv2d2[0][0]
#                                                                  block2_concat1[0][0]
# __________________________________________________________________________________________________
# block2_bn3 (BatchNormalization) (None, 23, 23, 131)  524         block2_concat2[0][0]
# __________________________________________________________________________________________________
# block2_actv3 (Activation)       (None, 23, 23, 131)  0           block2_bn3[0][0]
# __________________________________________________________________________________________________
# block2_pad3 (ZeroPadding2D)     (None, 25, 25, 131)  0           block2_actv3[0][0]
# __________________________________________________________________________________________________
# block2_conv2d3 (Conv2D)         (None, 23, 23, 72)   84960       block2_pad3[0][0]
# __________________________________________________________________________________________________
# block2_concat3 (Concatenate)    (None, 23, 23, 203)  0           block2_conv2d3[0][0]
#                                                                  block2_concat2[0][0]
# __________________________________________________________________________________________________
# transition2_bn (BatchNormalizat (None, 23, 23, 203)  812         block2_concat3[0][0]
# __________________________________________________________________________________________________
# transition2_actv (Activation)   (None, 23, 23, 203)  0           transition2_bn[0][0]
# __________________________________________________________________________________________________
# transition2_conv2d (Conv2D)     (None, 23, 23, 11)   2244        transition2_actv[0][0]
# __________________________________________________________________________________________________
# transition2_pool2d (AveragePool (None, 11, 11, 11)   0           transition2_conv2d[0][0]
# __________________________________________________________________________________________________
# block3_bn1 (BatchNormalization) (None, 11, 11, 11)   44          transition2_pool2d[0][0]
# __________________________________________________________________________________________________
# block3_actv1 (Activation)       (None, 11, 11, 11)   0           block3_bn1[0][0]
# __________________________________________________________________________________________________
# block3_pad1 (ZeroPadding2D)     (None, 13, 13, 11)   0           block3_actv1[0][0]
# __________________________________________________________________________________________________
# block3_conv2d1 (Conv2D)         (None, 11, 11, 84)   8400        block3_pad1[0][0]
# __________________________________________________________________________________________________
# block3_concat1 (Concatenate)    (None, 11, 11, 95)   0           block3_conv2d1[0][0]
#                                                                  transition2_pool2d[0][0]
# __________________________________________________________________________________________________
# block3_bn2 (BatchNormalization) (None, 11, 11, 95)   380         block3_concat1[0][0]
# __________________________________________________________________________________________________
# block3_actv2 (Activation)       (None, 11, 11, 95)   0           block3_bn2[0][0]
# __________________________________________________________________________________________________
# block3_pad2 (ZeroPadding2D)     (None, 13, 13, 95)   0           block3_actv2[0][0]
# __________________________________________________________________________________________________
# block3_conv2d2 (Conv2D)         (None, 11, 11, 96)   82176       block3_pad2[0][0]
# __________________________________________________________________________________________________
# block3_concat2 (Concatenate)    (None, 11, 11, 191)  0           block3_conv2d2[0][0]
#                                                                  block3_concat1[0][0]
# __________________________________________________________________________________________________
# block3_bn3 (BatchNormalization) (None, 11, 11, 191)  764         block3_concat2[0][0]
# __________________________________________________________________________________________________
# block3_actv3 (Activation)       (None, 11, 11, 191)  0           block3_bn3[0][0]
# __________________________________________________________________________________________________
# block3_pad3 (ZeroPadding2D)     (None, 13, 13, 191)  0           block3_actv3[0][0]
# __________________________________________________________________________________________________
# block3_conv2d3 (Conv2D)         (None, 11, 11, 108)  185760      block3_pad3[0][0]
# __________________________________________________________________________________________________
# block3_concat3 (Concatenate)    (None, 11, 11, 299)  0           block3_conv2d3[0][0]
#                                                                  block3_concat2[0][0]
# __________________________________________________________________________________________________
# transition3_bn (BatchNormalizat (None, 11, 11, 299)  1196        block3_concat3[0][0]
# __________________________________________________________________________________________________
# transition3_actv (Activation)   (None, 11, 11, 299)  0           transition3_bn[0][0]
# __________________________________________________________________________________________________
# transition3_conv2d (Conv2D)     (None, 11, 11, 5)    1500        transition3_actv[0][0]
# __________________________________________________________________________________________________
# transition3_pool2d (AveragePool (None, 5, 5, 5)      0           transition3_conv2d[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 5)            0           transition3_pool2d[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 5)            0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 128)          768         flatten_6[0][0]
# __________________________________________________________________________________________________
# dense1_bn (BatchNormalization)  (None, 128)          512         dense1[0][0]
# __________________________________________________________________________________________________
# dense1_actv (Activation)        (None, 128)          0           dense1_bn[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 3)            387         dense1_actv[0][0]
# ==================================================================================================
# Total params: 444,038
# Trainable params: 441,398
# Non-trainable params: 2,640
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True,
           dpi=50,)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    height_shift_range=0.08,
    shear_range=0.1,
    horizontal_flip=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.1,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.0005,
    patience=12,
    verbose=1,
    restore_best_weights=True,
)

# %%
BEST_CONFIG = {
    "batch_size": 32,
    "epochs": 75,
    "loss": "categorical_crossentropy",
    "optim": optimizers.Adam(0.001),
}

# %%
run = wandb.init(project="densenet_fer")
config = run.config

config.batch_size = BEST_CONFIG["batch_size"]
config.loss = BEST_CONFIG["loss"]
config.optim = "Adam(0.001)"
config.epochs = BEST_CONFIG["epochs"]
config.lr_schedule = lr_scheduler.factor
config.early_stop = early_stopping.patience
config.num_classes = NUM_CLASSES
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/gauravsharma/densenet_fer" target="_blank">https://app.wandb.ai/gauravsharma/densenet_fer</a><br/>
#                 Run page: <a href="https://app.wandb.ai/gauravsharma/densenet_fer/runs/3ala7a8q" target="_blank">https://app.wandb.ai/gauravsharma/densenet_fer/runs/3ala7a8q</a><br/>
# Error in callback <function _init_jupyter.<locals>.cleanup at 0x7fd1ebb43840> (for post_run_cell):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/wandb/__init__.py in cleanup()
#     504         # shutdown async logger because _user_process_finished isn't called in jupyter
#     505         shutdown_async_log_thread()
# --> 506         run._stop_jupyter_agent()
#     507     if hasattr(ipython.events, "_orig_post_run"):
#     508         ipython.events.unregister("post_run_cell", ipython.events._orig_post_run)
#
# /usr/local/lib/python3.6/dist-packages/wandb/wandb_run.py in _stop_jupyter_agent(self)
#     198
#     199     def _stop_jupyter_agent(self):
# --> 200         self._jupyter_agent.stop()
#     201
#     202     def send_message(self, options):
#
# /usr/local/lib/python3.6/dist-packages/wandb/jupyter.py in stop(self)
#     140             self.rm.unmirror_stdout_stderr()
#     141             wandb.run.close_files()
# --> 142             self.rm.shutdown()
#     143             self.paused = True
#     144
#
# /usr/local/lib/python3.6/dist-packages/wandb/run_manager.py in shutdown(self, exitcode)
#    1084         if self._cloud:
#    1085             logger.info("stopping streaming files and file change observer")
# -> 1086             self._end_file_syncing(exitcode)
#    1087
#    1088
#
# /usr/local/lib/python3.6/dist-packages/wandb/run_manager.py in _end_file_syncing(self, exitcode)
#     670             handler.finish()
#     671         self._file_pusher.finish()
# --> 672         self._api.get_file_stream_api().finish(exitcode)
#     673         # In Jupyter notebooks, wandb.init can be called multiple times in the same
#     674         # process, creating new runs each time. This ensures we get a new file stream
#
# /usr/local/lib/python3.6/dist-packages/wandb/apis/file_stream.py in finish(self, exitcode)
#     273         """
#     274         self._queue.put(self.Finish(exitcode))
# --> 275         self._thread.join()
#
# /usr/lib/python3.6/threading.py in join(self, timeout)
#    1054
#    1055         if timeout is None:
# -> 1056             self._wait_for_tstate_lock()
#    1057         else:
#    1058             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.6/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1070         if lock is None:  # already determined that the C code is done
#    1071             assert self._is_stopped
# -> 1072         elif lock.acquire(block, timeout):
#    1073             lock.release()
#    1074             self._stop()
#
# KeyboardInterrupt:

# %%
model.compile(
        loss=BEST_CONFIG["loss"],
        optimizer=BEST_CONFIG["optim"],
        metrics=['accuracy']
)

train_datagen.fit(X_train)
history = model.fit(
    train_datagen.flow(X_train, y_train, batch_size=BEST_CONFIG["batch_size"]),
    validation_data=(X_test, y_test),
    steps_per_epoch=len(X_train) / BEST_CONFIG["batch_size"],
    epochs=BEST_CONFIG["epochs"],
    callbacks=[lr_scheduler, early_stopping, WandbCallback()],
)
# Out:
# Epoch 1/75
# 124/123 [==============================] - 8s 67ms/step - loss: 1.0530 - accuracy: 0.4750 - val_loss: 1.0519 - val_accuracy: 0.4837 - lr: 0.0010
# Epoch 2/75
# 124/123 [==============================] - 8s 63ms/step - loss: 0.8968 - accuracy: 0.5661 - val_loss: 1.0279 - val_accuracy: 0.4806 - lr: 0.0010
# Epoch 3/75
# 124/123 [==============================] - 8s 63ms/step - loss: 0.7068 - accuracy: 0.6695 - val_loss: 0.7464 - val_accuracy: 0.6190 - lr: 0.0010
# Epoch 4/75
# 124/123 [==============================] - 8s 63ms/step - loss: 0.6691 - accuracy: 0.6825 - val_loss: 0.6897 - val_accuracy: 0.6812 - lr: 0.0010
# Epoch 5/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.6259 - accuracy: 0.7165 - val_loss: 1.1208 - val_accuracy: 0.6314 - lr: 0.0010
# Epoch 6/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.5981 - accuracy: 0.7286 - val_loss: 0.7144 - val_accuracy: 0.6781 - lr: 0.0010
# Epoch 7/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.5703 - accuracy: 0.7433 - val_loss: 1.3034 - val_accuracy: 0.6112 - lr: 0.0010
# Epoch 8/75
# 123/123 [============================>.] - ETA: 0s - loss: 0.5507 - accuracy: 0.7609
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 124/123 [==============================] - 8s 61ms/step - loss: 0.5502 - accuracy: 0.7613 - val_loss: 1.0132 - val_accuracy: 0.6594 - lr: 0.0010
# Epoch 9/75
# 124/123 [==============================] - 8s 63ms/step - loss: 0.4956 - accuracy: 0.7875 - val_loss: 0.4977 - val_accuracy: 0.7729 - lr: 1.0000e-04
# Epoch 10/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4870 - accuracy: 0.7908 - val_loss: 0.5159 - val_accuracy: 0.7683 - lr: 1.0000e-04
# Epoch 11/75
# 124/123 [==============================] - 8s 63ms/step - loss: 0.4728 - accuracy: 0.7986 - val_loss: 0.4862 - val_accuracy: 0.7714 - lr: 1.0000e-04
# Epoch 12/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4660 - accuracy: 0.8017 - val_loss: 0.5046 - val_accuracy: 0.7714 - lr: 1.0000e-04
# Epoch 13/75
# 123/123 [============================>.] - ETA: 0s - loss: 0.4615 - accuracy: 0.8056
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4609 - accuracy: 0.8060 - val_loss: 0.5743 - val_accuracy: 0.7481 - lr: 1.0000e-04
# Epoch 14/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4487 - accuracy: 0.8052 - val_loss: 0.4996 - val_accuracy: 0.7792 - lr: 1.0000e-05
# Epoch 15/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4397 - accuracy: 0.8182 - val_loss: 0.4906 - val_accuracy: 0.7869 - lr: 1.0000e-05
# Epoch 16/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4427 - accuracy: 0.8128 - val_loss: 0.4874 - val_accuracy: 0.7823 - lr: 1.0000e-05
# Epoch 17/75
# 124/123 [==============================] - 8s 64ms/step - loss: 0.4410 - accuracy: 0.8194 - val_loss: 0.4828 - val_accuracy: 0.7885 - lr: 1.0000e-05
# Epoch 18/75
# 124/123 [==============================] - 8s 63ms/step - loss: 0.4440 - accuracy: 0.8123 - val_loss: 0.4822 - val_accuracy: 0.7885 - lr: 1.0000e-05
# Epoch 19/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4422 - accuracy: 0.8177 - val_loss: 0.4849 - val_accuracy: 0.7869 - lr: 1.0000e-05
# Epoch 20/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4297 - accuracy: 0.8156 - val_loss: 0.4856 - val_accuracy: 0.7854 - lr: 1.0000e-05
# Epoch 21/75
# 123/123 [============================>.] - ETA: 0s - loss: 0.4472 - accuracy: 0.8097
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4471 - accuracy: 0.8095 - val_loss: 0.4889 - val_accuracy: 0.7854 - lr: 1.0000e-05
# Epoch 22/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4396 - accuracy: 0.8118 - val_loss: 0.4870 - val_accuracy: 0.7854 - lr: 1.0000e-06
# Epoch 23/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4374 - accuracy: 0.8187 - val_loss: 0.4866 - val_accuracy: 0.7854 - lr: 1.0000e-06
# Epoch 24/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4280 - accuracy: 0.8240 - val_loss: 0.4858 - val_accuracy: 0.7869 - lr: 1.0000e-06
# Epoch 25/75
# 123/123 [============================>.] - ETA: 0s - loss: 0.4336 - accuracy: 0.8201
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4337 - accuracy: 0.8202 - val_loss: 0.4858 - val_accuracy: 0.7869 - lr: 1.0000e-06
# Epoch 26/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4362 - accuracy: 0.8131 - val_loss: 0.4865 - val_accuracy: 0.7869 - lr: 1.0000e-07
# Epoch 27/75
# 124/123 [==============================] - 7s 60ms/step - loss: 0.4320 - accuracy: 0.8169 - val_loss: 0.4865 - val_accuracy: 0.7869 - lr: 1.0000e-07
# Epoch 28/75
# 124/123 [==============================] - 8s 61ms/step - loss: 0.4320 - accuracy: 0.8171 - val_loss: 0.4861 - val_accuracy: 0.7854 - lr: 1.0000e-07
# Epoch 29/75
# 123/123 [============================>.] - ETA: 0s - loss: 0.4344 - accuracy: 0.8158
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1e-07.
# Restoring model weights from the end of the best epoch.
# 124/123 [==============================] - 8s 62ms/step - loss: 0.4382 - accuracy: 0.8146 - val_loss: 0.4877 - val_accuracy: 0.7854 - lr: 1.0000e-07
# Epoch 00029: early stopping

# %%
sns.set()
fig = pyplot.figure(0, (12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(history.epoch, history.history['accuracy'], label='train')
sns.lineplot(history.epoch, history.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(history.epoch, history.history['loss'], label='train')
sns.lineplot(history.epoch, history.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

# pyplot.savefig(BASE_PATH+f'epoch_metrics/cnn_{DATA}_{NUM_CLASSES}emo.png')
pyplot.show()

# %%
label_to_text
# Out:
# {0: 'Happy', 1: 'Neutral', 2: 'Sadness'}

# %%
yhat_test = np.argmax(model.predict(X_test), axis=1)
ytest_ = np.argmax(y_test, axis=1)

scikitplot.metrics.plot_confusion_matrix(ytest_, yhat_test, figsize=(7,7))
# pyplot.savefig(BASE_PATH+f"confusion_matrix/cnn_{DATA}_{NUM_CLASSES}emo.png")

test_accu = np.sum(ytest_ == yhat_test) / len(ytest_) * 100
print(f"test accuracy: {round(test_accu, 4)} %\n\n")

print(classification_report(ytest_, yhat_test))
# Out:
# test accuracy: 78.8491 %
#
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       309
#            1       0.62      0.73      0.67       172
#            2       0.71      0.59      0.64       162
#
#     accuracy                           0.79       643
#    macro avg       0.75      0.75      0.75       643
# weighted avg       0.79      0.79      0.79       643

# %%
yhat_train = np.argmax(model.predict(X_train), axis=1)
ytrain_ = np.argmax(y_train, axis=1)

train_accu = np.sum(ytrain_ == yhat_train) / len(ytrain_) * 100
print(f"train accuracy: {round(train_accu, 4)} %")
# Out:
# train accuracy: 82.1963 %
